# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f542dbfa5144> in <module>
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd

# %%
pd._versionn_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-01bcbbffa5e7> in <module>
# ----> 1 pd._versionn_
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute '_versionn_'

# %%
pd._version_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-1df133d9fdb7> in <module>
# ----> 1 pd._version_
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute '_version_'

# %%
pd.__version__
# Out:
# '1.0.3'

# %%
pd.read_excel("aSSER REG_updated.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-ed208eccc1d9> in <module>
# ----> 1 pd.read_excel("aSSER REG_updated.xls")
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
# ...

# %%
pd.read_excel("aSSETREG_updated.xls")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-f39edc7dbd45> in <module>
# ----> 1 pd.read_excel("aSSETREG_updated.xls")
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
# ...

# %%
pd.read_excel("aSSETREG_updated.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-2c8e4f386720> in <module>
# ----> 1 pd.read_excel("aSSETREG_updated.xlsx")
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
# ...

# %%
pd.read_excel('C:\Users\TMFL\aSSET_REG.xlsx')
# Out:
#   File "<ipython-input-10-ffd07151c999>", line 1
#     pd.read_excel('C:\Users\TMFL\aSSET_REG.xlsx')
#                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx')
# Out:
#     Unnamed: 0  Unnamed: 1       HostName Asset Type    Make SerialNumber  \
# 0          NaN         NaN   INPCTCS05987    DESKTOP  ZENITH      3X09688
# 1          NaN         NaN   INPCTCS05066    DESKTOP  ZENITH      2Y17400
# 2          NaN         NaN   INPCTCS05065    DESKTOP  ZENITH      2Y17391
# 3          NaN         NaN   INPCTCS05985    DESKTOP  ZENITH      3Y10493
# 4          NaN         NaN   INPCTCS05919    DESKTOP  ZENITH      3Y11196
# 5          NaN         NaN  INLTTTCS02629     LAPTOP      HP   CND1343ZXW
# 6          NaN         NaN  INLTTTCS04171     LAPTOP      HP   INA310Y8SW
# 7          NaN         NaN  INLTTTCS03605     LAPTOP      HP   INA304VYK2
# 8          NaN         NaN  INLTTTCS03356     LAPTOP      HP   5CB22023XS
# 9          NaN         NaN  INLTTTCS04484     LAPTOP      HP   INA402QKY6
# 10         NaN         NaN  INLTTTCS06726     LAPTOP      HP   5CB42504GC
# 11         NaN         NaN  INLTTTCS03659     LAPTOP      HP   INA304VYMR
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',indexcol=3)
# Out:
#     Unnamed: 0  Unnamed: 1       HostName Asset Type    Make SerialNumber  \
# 0          NaN         NaN   INPCTCS05987    DESKTOP  ZENITH      3X09688
# 1          NaN         NaN   INPCTCS05066    DESKTOP  ZENITH      2Y17400
# 2          NaN         NaN   INPCTCS05065    DESKTOP  ZENITH      2Y17391
# 3          NaN         NaN   INPCTCS05985    DESKTOP  ZENITH      3Y10493
# 4          NaN         NaN   INPCTCS05919    DESKTOP  ZENITH      3Y11196
# 5          NaN         NaN  INLTTTCS02629     LAPTOP      HP   CND1343ZXW
# 6          NaN         NaN  INLTTTCS04171     LAPTOP      HP   INA310Y8SW
# 7          NaN         NaN  INLTTTCS03605     LAPTOP      HP   INA304VYK2
# 8          NaN         NaN  INLTTTCS03356     LAPTOP      HP   5CB22023XS
# 9          NaN         NaN  INLTTTCS04484     LAPTOP      HP   INA402QKY6
# 10         NaN         NaN  INLTTTCS06726     LAPTOP      HP   5CB42504GC
# 11         NaN         NaN  INLTTTCS03659     LAPTOP      HP   INA304VYMR
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3)
# Out:
#             Unnamed: 0  Unnamed: 1       HostName    Make SerialNumber  \
# Asset Type
# DESKTOP            NaN         NaN   INPCTCS05987  ZENITH      3X09688
# DESKTOP            NaN         NaN   INPCTCS05066  ZENITH      2Y17400
# DESKTOP            NaN         NaN   INPCTCS05065  ZENITH      2Y17391
# DESKTOP            NaN         NaN   INPCTCS05985  ZENITH      3Y10493
# DESKTOP            NaN         NaN   INPCTCS05919  ZENITH      3Y11196
# LAPTOP             NaN         NaN  INLTTTCS02629      HP   CND1343ZXW
# LAPTOP             NaN         NaN  INLTTTCS04171      HP   INA310Y8SW
# LAPTOP             NaN         NaN  INLTTTCS03605      HP   INA304VYK2
# LAPTOP             NaN         NaN  INLTTTCS03356      HP   5CB22023XS
# LAPTOP             NaN         NaN  INLTTTCS04484      HP   INA402QKY6
# LAPTOP             NaN         NaN  INLTTTCS06726      HP   5CB42504GC
# LAPTOP             NaN         NaN  INLTTTCS03659      HP   INA304VYMR
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,header=0)
# Out:
#             Unnamed: 0  Unnamed: 1       HostName    Make SerialNumber  \
# Asset Type
# DESKTOP            NaN         NaN   INPCTCS05987  ZENITH      3X09688
# DESKTOP            NaN         NaN   INPCTCS05066  ZENITH      2Y17400
# DESKTOP            NaN         NaN   INPCTCS05065  ZENITH      2Y17391
# DESKTOP            NaN         NaN   INPCTCS05985  ZENITH      3Y10493
# DESKTOP            NaN         NaN   INPCTCS05919  ZENITH      3Y11196
# LAPTOP             NaN         NaN  INLTTTCS02629      HP   CND1343ZXW
# LAPTOP             NaN         NaN  INLTTTCS04171      HP   INA310Y8SW
# LAPTOP             NaN         NaN  INLTTTCS03605      HP   INA304VYK2
# LAPTOP             NaN         NaN  INLTTTCS03356      HP   5CB22023XS
# LAPTOP             NaN         NaN  INLTTTCS04484      HP   INA402QKY6
# LAPTOP             NaN         NaN  INLTTTCS06726      HP   5CB42504GC
# LAPTOP             NaN         NaN  INLTTTCS03659      HP   INA304VYMR
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,usecols="A:D")
# Out:
#             Unnamed: 0  Unnamed: 1       HostName
# Asset Type
# DESKTOP            NaN         NaN   INPCTCS05987
# DESKTOP            NaN         NaN   INPCTCS05066
# DESKTOP            NaN         NaN   INPCTCS05065
# DESKTOP            NaN         NaN   INPCTCS05985
# DESKTOP            NaN         NaN   INPCTCS05919
# LAPTOP             NaN         NaN  INLTTTCS02629
# LAPTOP             NaN         NaN  INLTTTCS04171
# LAPTOP             NaN         NaN  INLTTTCS03605
# LAPTOP             NaN         NaN  INLTTTCS03356
# LAPTOP             NaN         NaN  INLTTTCS04484
# LAPTOP             NaN         NaN  INLTTTCS06726
# LAPTOP             NaN         NaN  INLTTTCS03659
# LAPTOP             NaN         NaN  INLTTTCS07201
# LAPTOP             NaN         NaN  INLTTTCS04482
# LAPTOP             NaN         NaN  INLTTTCS06124
# LAPTOP             NaN         NaN  INLTTTCS06853
# LAPTOP             NaN         NaN   INLTTTCS0449
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx')
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0          NaN         NaN      SL No  Domain ID      Location      Hostname
# 1          NaN         NaN          1   99305693  Bangalore RO  INPCTCS08905
# 2          NaN         NaN          2   99305685  Bangalore RO  INPCTCS08055
# 3          NaN         NaN          3   88000540  Bangalore RO  INPCTCS04006
# 4          NaN         NaN          4     520549  Bangalore RO  INPCTCS05064
# ..         ...         ...        ...        ...           ...           ...
# 92         NaN         NaN         92   99303246  Bangalore RO  INPCTCS05064
# 93         NaN         NaN         93        NaN  Bangalore RO  INPCTCS05893
# 94         NaN         NaN         94   99500016  Bangalore RO  INPCTCS06080
# 95         NaN         NaN         95   99015992  Bangalore RO  INPCTCS00683
# 96         NaN         NaN         96   99303619  Bangalore RO  INPCTCS08054
#
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3)
# Out:
#            Unnamed: 0  Unnamed: 1 Unnamed: 2    Unnamed: 4    Unnamed: 5  \
# Domain ID         NaN         NaN      SL No      Location      Hostname
# 99305693          NaN         NaN          1  Bangalore RO  INPCTCS08905
# 99305685          NaN         NaN          2  Bangalore RO  INPCTCS08055
# 88000540          NaN         NaN          3  Bangalore RO  INPCTCS04006
# 520549            NaN         NaN          4  Bangalore RO  INPCTCS05064
# ...               ...         ...        ...           ...           ...
# 99303246          NaN         NaN         92  Bangalore RO  INPCTCS05064
# NaN               NaN         NaN         93  Bangalore RO  INPCTCS05893
# 99500016          NaN         NaN         94  Bangalore RO  INPCTCS06080
# 99015992          NaN         NaN         95  Bangalore RO  INPCTCS00683
# 99303619          NaN         NaN         96  Bangalore RO  INPCTCS08054
#
#            Unnamed: 6 Unnamed: 7 Unnamed: 8     Unnamed: 9  \
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=2
             )
# Out:
#        Unnamed: 0  Unnamed: 1 Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# SL No         NaN         NaN  Domain ID      Location      Hostname
# 1             NaN         NaN   99305693  Bangalore RO  INPCTCS08905
# 2             NaN         NaN   99305685  Bangalore RO  INPCTCS08055
# 3             NaN         NaN   88000540  Bangalore RO  INPCTCS04006
# 4             NaN         NaN     520549  Bangalore RO  INPCTCS05064
# ...           ...         ...        ...           ...           ...
# 92            NaN         NaN   99303246  Bangalore RO  INPCTCS05064
# 93            NaN         NaN        NaN  Bangalore RO  INPCTCS05893
# 94            NaN         NaN   99500016  Bangalore RO  INPCTCS06080
# 95            NaN         NaN   99015992  Bangalore RO  INPCTCS00683
# 96            NaN         NaN   99303619  Bangalore RO  INPCTCS08054
#
#        Unnamed: 6 Unnamed: 7 Unnamed: 8     Unnamed: 9  \
# SL No  Asset Type       Make      Model  Serial number
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,header=1
             )
# Out:
#             Unnamed: 0  Unnamed: 1  SL No      Location      Hostname  \
# Domain ID
# 99305693.0         NaN         NaN      1  Bangalore RO  INPCTCS08905
# 99305685.0         NaN         NaN      2  Bangalore RO  INPCTCS08055
# 88000540.0         NaN         NaN      3  Bangalore RO  INPCTCS04006
# 520549.0           NaN         NaN      4  Bangalore RO  INPCTCS05064
# 99303615.0         NaN         NaN      5  Bangalore RO  INPCTCS05065
# ...                ...         ...    ...           ...           ...
# 99303246.0         NaN         NaN     92  Bangalore RO  INPCTCS05064
# NaN                NaN         NaN     93  Bangalore RO  INPCTCS05893
# 99500016.0         NaN         NaN     94  Bangalore RO  INPCTCS06080
# 99015992.0         NaN         NaN     95  Bangalore RO  INPCTCS00683
# 99303619.0         NaN         NaN     96  Bangalore RO  INPCTCS08054
#
#            Asset Type    Make   Model Serial number                 Username  \
# Domain ID
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3)
# Out:
#            Unnamed: 0  Unnamed: 1 Unnamed: 2    Unnamed: 4    Unnamed: 5  \
# Domain ID         NaN         NaN      SL No      Location      Hostname
# 99305693          NaN         NaN          1  Bangalore RO  INPCTCS08905
# 99305685          NaN         NaN          2  Bangalore RO  INPCTCS08055
# 88000540          NaN         NaN          3  Bangalore RO  INPCTCS04006
# 520549            NaN         NaN          4  Bangalore RO  INPCTCS05064
# ...               ...         ...        ...           ...           ...
# 99303246          NaN         NaN         92  Bangalore RO  INPCTCS05064
# NaN               NaN         NaN         93  Bangalore RO  INPCTCS05893
# 99500016          NaN         NaN         94  Bangalore RO  INPCTCS06080
# 99015992          NaN         NaN         95  Bangalore RO  INPCTCS00683
# 99303619          NaN         NaN         96  Bangalore RO  INPCTCS08054
#
#            Unnamed: 6 Unnamed: 7 Unnamed: 8     Unnamed: 9  \
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,usecols=[2,3,4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-ddcb87821abc> in <module>
# ----> 1 pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,usecols=[2,3,4])
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     332         convert_float=convert_float,
#     333         mangle_dupe_cols=mangle_dupe_cols,
# --> 334         **kwds,
#     335     )
#     336
#
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheetname=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-98acdd1ff5f5> in <module>
# ----> 1 pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheetname=1)
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     299     for arg in ("sheet", "sheetname", "parse_cols"):
#     300         if arg in kwds:
# --> 301             raise TypeError(f"read_excel() got an unexpected keyword argument `{arg}`")
#     302
#     303     if not isinstance(io, ExcelFile):
#
# TypeError: read_excel() got an unexpected keyword argument `sheetname`

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheet_name=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-e626da8450f4> in <module>
# ----> 1 pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheet_name=1)
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     332         convert_float=convert_float,
#     333         mangle_dupe_cols=mangle_dupe_cols,
# --> 334         **kwds,
#     335     )
#     336
#
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheetname=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-54ff0f348801> in <module>
# ----> 1 pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheetname=0)
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     299     for arg in ("sheet", "sheetname", "parse_cols"):
#     300         if arg in kwds:
# --> 301             raise TypeError(f"read_excel() got an unexpected keyword argument `{arg}`")
#     302
#     303     if not isinstance(io, ExcelFile):
#
# TypeError: read_excel() got an unexpected keyword argument `sheetname`

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheet_name=0)
# Out:
#            Unnamed: 0  Unnamed: 1 Unnamed: 2    Unnamed: 4    Unnamed: 5  \
# Domain ID         NaN         NaN      SL No      Location      Hostname
# 99305693          NaN         NaN          1  Bangalore RO  INPCTCS08905
# 99305685          NaN         NaN          2  Bangalore RO  INPCTCS08055
# 88000540          NaN         NaN          3  Bangalore RO  INPCTCS04006
# 520549            NaN         NaN          4  Bangalore RO  INPCTCS05064
# ...               ...         ...        ...           ...           ...
# 99303246          NaN         NaN         92  Bangalore RO  INPCTCS05064
# NaN               NaN         NaN         93  Bangalore RO  INPCTCS05893
# 99500016          NaN         NaN         94  Bangalore RO  INPCTCS06080
# 99015992          NaN         NaN         95  Bangalore RO  INPCTCS00683
# 99303619          NaN         NaN         96  Bangalore RO  INPCTCS08054
#
#            Unnamed: 6 Unnamed: 7 Unnamed: 8     Unnamed: 9  \
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheet_name=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-e626da8450f4> in <module>
# ----> 1 pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheet_name=1)
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     332         convert_float=convert_float,
#     333         mangle_dupe_cols=mangle_dupe_cols,
# --> 334         **kwds,
#     335     )
#     336
#
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheet_name=2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-43659917d4c9> in <module>
# ----> 1 pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',index_col=3,sheet_name=2)
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     332         convert_float=convert_float,
#     333         mangle_dupe_cols=mangle_dupe_cols,
# --> 334         **kwds,
#     335     )
#     336
#
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',sheet_name=0)
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0          NaN         NaN      SL No  Domain ID      Location      Hostname
# 1          NaN         NaN          1   99305693  Bangalore RO  INPCTCS08905
# 2          NaN         NaN          2   99305685  Bangalore RO  INPCTCS08055
# 3          NaN         NaN          3   88000540  Bangalore RO  INPCTCS04006
# 4          NaN         NaN          4     520549  Bangalore RO  INPCTCS05064
# ..         ...         ...        ...        ...           ...           ...
# 92         NaN         NaN         92   99303246  Bangalore RO  INPCTCS05064
# 93         NaN         NaN         93        NaN  Bangalore RO  INPCTCS05893
# 94         NaN         NaN         94   99500016  Bangalore RO  INPCTCS06080
# 95         NaN         NaN         95   99015992  Bangalore RO  INPCTCS00683
# 96         NaN         NaN         96   99303619  Bangalore RO  INPCTCS08054
#
# ...

# %%
pd.read_excel(r'C:\Users\TMFL\aSSET_REG.xlsx',sheet_name=1)
# Out:
# Empty DataFrame
# Columns: [this is sheet 1]
# Index: []
